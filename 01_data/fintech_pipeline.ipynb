# %% [markdown]
# # Part 3: Python Reconciliation Workflow
# # (code already runs via reconciliation.py)
# # Results saved to processed/ folder
#
# # Part 4: JSON Normalization
# # (code already runs via full_pipeline.py)
# # Results saved to api_normalized.csv
